# %%
import os
os.chdir('../')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ruwordnet import RuWordNet
import pickle
from search import normalize_string
import pymorphy3
from functools import reduce
wn = RuWordNet()
morph = pymorphy3.MorphAnalyzer()

# %%
from search import *

# %%
enrich_query('банковский сектор')
# Out:
# ['секторах',
#  'отделам',
#  'составной',
#  'отделами',
#  'структурен',
#  'подразделенье',
#  'подразделеньями',
#  'подразделение',
#  'кругом',
#  'составное',
#  'составных',
#  'отделов',
#  'учрежденьем',
#  'отделу',
#  'частью',
#  'учрежденьям',
#  'подразделеньях',
#  'структурнее',
#  'учрежденьями',
#  'отдела',
#  'подразделенью',
#  'подразделений',
#  'структурным',
#  'отделе',
#  'банковское',
#  'участки',
#  'банковского',
#  'частей',
#  'банковском',
#  'сфер',
#  'сектор',
#  'структурными',
#  'банковская',
#  'финансовыми',
#  'сферой',
#  'сферами',
#  'участке',
#  'учрежденья',
#  'банковские',
#  'учреждением',
#  'банкам',
#  'финансовом',
#  'учреждений',
#  'финансовые',
#  'финансовый',
#  'организациями',
#  'подразделению',
#  'банками',
#  'кругу',
#  'деятельностями',
#  'организацией',
#  'банковскому',
#  'подразделеньем',
#  'составнее',
#  'структурною',
#  'составными',
#  'учреждениями',
#  'сфера',
#  'территорий',
#  'пофинансовей',
# ...
